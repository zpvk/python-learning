# %% [markdown]
# Low of Lage Numbers

# %%
import numpy as np
from numpy.random import randn
V = 100000
dataframe=[]
count = 0
for i in randn(N):
   if (i > -1 and i < 1):
        count = count + 1
X = count/V
print(X)
# Out:
# 1e-05
